# %% [markdown]
# # مفهوم المتغيرات
#
#
# المتغيرات ( variables ) عبارة عن أماكن يتم حجزها في الذاكرة بهدف تخزين بيانات فيها أثناء تشغيل البرنامج.
#
#
# في بايثون, المبرمج غير مسؤول عن تحديد أنواع المتغيرات التي يعرّفها في برنامجه.
#
#
# فعلياً, عندما تقوم بتعريف متغير و تضع فيه أي قيمة, سيقوم مفسّر لغة بايثون بتحديد نوع هذا المتغير بناءاً على القيمة التي أسندتها إليه بشكل تلقائي وقت التشغيل.
#
#
# في بايثون يجب إسناد قيمة إلى المتغير أثناء تعريفه.

# %% [markdown]
# ## معرفة نوع المتغير
#
# لمعرفة نوع أي متغير يمكنك إستخدام الدالة type
#
# تذكر: نوع المتغير في بايثون غير ثابت لأنه يتغير بشكل تلقائي على حسب نوع القيمة التي يتم تخزينها فيه.

# %% [markdown]
# type(variable) => variable type

# %%
# integer
var = 10

# %%
print(type(var))
# Out:
# <class 'bool'>

# %%
var = "a"

# %%
# string
type(var)
# Out:
# bool

# %%
# boolean
var = True

# %%
print(type(var))
# Out:
# <class 'bool'>

# %% [markdown]
# ## أنواع المتغيرات في بايثون
#
# تنقسم أنواع المتغيرات في بايثون إلى 7 أنواع أساسية و هي:
#
# - أرقام (Numbers).
# - نصوص (Strings).
# - منطقية (Booleans).
# - مصفوفات ليس لها حجم ثابت يقال لها Lists.
# - مصفوفات حجمها و قيمها ثابتة, و غير قابلة للتغيير يقال لها Tuples.
# - مصفوفات ليس لها حجم ثابت, و لا يمكن حذف قيمها, و يمكن إضافة قيم جديدة فيها يقال لها Sets.
# - جداول تخزن البيانات فيها بطريقة مفايتح (Keys) و قيم (Values) يقال لها Dictionaries.

# %% [markdown]
# <center>
#
#
# ## الهدف من الجزئيه القادمه هي التدريب علي انواع المتغيرات
#
# ##### أرقام (Numbers).
# ##### نصوص (Strings).
# ##### منطقية (Booleans).
#
# ## شد الحزام و خليك جاهز
#
#
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)
#
# </center>

# %% [markdown]
# ## الأرقام
#
# عند تعريف متغير و تخزين رقم فيه, فإن مفسّر لغة بايثون سيقوم بشكل تلقائي بتحديد نوع هذا المتغير بناءاً على نوع القيمة الرقمية التي تم إسنادها إليه.
#
# فإذا وضعت فيه عدد صحيح, يصبح نوعه int. و إذا وضعت فيه عدد عشري ( أي يحتوي على فاصلة ), يصبح نوعه float و هكذا.

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = 3            # قيمته عبارة عن عدد صحيح ,x هنا قمنا بتعريف متغير إسمه
y = 1.5          #  قيمته عبارة عن عدد عشري ,y هنا قمنا بتعريف متغير إسمه
z = 4J           #   قيمته عبارة عن عدد مركب ,z هنا قمنا بتعريف متغير إسمه

# %%
print(x)
# Out:
# 3

# %%
print(type(x))
# Out:
# <class 'int'>

# %%
print(y)
print(type(y))
# Out:
# 1.5
# <class 'float'>

# %%
print(z)
print(type(z))
# Out:
# 4j
# <class 'complex'>

# %% [markdown]
# ## معظم العمل سوف يكون علي الانواع الاتيه
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## النصوص strings
#
# لتعريف نص في بايثون نستخدم الرمز ' أو الرمز " أو الرمز """.
#
#
# هل يوجد فرق بين هذه الرموز؟
#
# بالنسبة للرمز ' و الرمز " فإنه لا يوجد أي فرق بينهما. و يمكن إستخدام أي واحد منهما لتعريف نص يتألف من سطر واحد.
#
# بالنسبة للرمز ''' و الرمز """ فإنه لا يوجد أي فرق بينهما. و يمكن إستخدام أي واحد منهما لتعريف نص كبير يتألف من عدة أسطر.

# %% [markdown]
# examples for using '', "" for creating strings

# %%
print("hello")
# Out:
# 'hello'

# %%
print('how are you')
# Out:
# how are you

# %%
print("hello 
how are you")
# Out:
#   Input In [39]
#     print("hello
#                  ^
# SyntaxError: EOL while scanning string literal

# %% [markdown]
# عندما نلاحظ الخطا الماضي
# نجد اننا لا يمكن ان نكتب نص في اكثر من سطر باستخدام ال "" و '' عندما نقوم بعمل ال string
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# اذن كيف يمكننا عمل نص في اكثر من سطر

# %% [markdown]
# example for using """ """, ''' ''' in multiline strings

# %%
print("""
hello
how are you
""")
# Out:
# hello
# how are you

# %%
# example: My BIO

name = "Omer Ali"
age = "25"
profession = "Business Man"
bio = """I have been in Sudan for 24 years 
then I have started my own restaurant 
and I was selling flafel for the last 2 year of my life"""

print(name)
print(age)
print(profession)
print(bio)
# Out:
# Omer Ali
# 25
# Business Man
# I have been in Sudan for 24 years
# then I have started my own restaurant
# and I was selling flafel for the last 2 year of my life

# %% [markdown]
# ## القيم المنطقية
#
# النوع bool يستخدم في العادة عند وضع شروط منطقية أو لمعرفة ما إذا تم تنفيذ أمر معين بنجاح أم لا. <br>
# عند إسناد القيمة True أو القيمة False إلى المتغير فإنه يصبح من النوع bool.

# %% [markdown]
# ## معلومة تقنية
#
# في الواقع القيمة True تساوي 1 و القيمة False تساوي 0. <br>
# في بايثون يفضل إستخدام الصفر و الواحد بدلاً من إستخدام القيم المحجوزة True و False عند التشييك على قيمة المتغير أو على ما سترجعه الدالة.

# %%
print(True)
# Out:
# True

# %%
type(True)
# Out:
# bool

# %%
print(type(True))
# Out:
# <class 'bool'>

# %%
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [48], in <cell line: 1>()
# ----> 1 true
#
# NameError: name 'true' is not defined

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
False
# Out:
# False

# %%
print(type(False))
# Out:
# <class 'bool'>

# %%
type(False)
# Out:
# bool

# %% [markdown]
# ## Bug in code
#
# ![image.png](attachment:image.png)

# %%
false
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [52], in <cell line: 1>()
# ----> 1 false
#
# NameError: name 'false' is not defined

# %% [markdown]
# ## هل يمكنك وصف الانسان بمتغيرات و طباعة انواعها
#
# ![image.png](attachment:image.png)

# %% [markdown]
# اولا: نقوم بتعريف المتغيرات

# %%
length = "tall"
is_student = False
body_color = "brown"
hair_color = "black"
weight = 15.7
age = 15

# %% [markdown]
# ثانيا: نقوم بطباعة قيم المتغيرات

# %%
print(lngth)
print(is_student)
print(body_color)
print(haircolor)
print(wight)
print(ge)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [62], in <cell line: 1>()
# ----> 1 print(lngth)
#       2 print(is_student)
#       3 print(body_color)
#
# NameError: name 'lngth' is not defined

# %% [markdown]
# هناك مشكله في الكود, اذا لم تكتب اسامي المتغيرات بصوره صحيحه عندما تقوم بالطباعة يعطيك خطا
#
# is not defined
#
# ![image.png](attachment:image.png)

# %%
print(length)
print(is_student)
print(body_color)
print(hair_color)
print(weight)
print(age)
# Out:
# tall
# False
# brown
# black
# 15.7
# 15

# %% [markdown]
# ثالثا: نقوم بطباعة انواع المتغيرات

# %%
print(type(length))
print(type(is_student))
print(type(body_color))
print(type(hair_color))
print(type(weight))
print(type(age))
# Out:
# <class 'str'>
# <class 'bool'>
# <class 'str'>
# <class 'str'>
# <class 'float'>
# <class 'int'>

# %% [markdown]
# ## هل يمكنك وصف الصوره بمتغيرات و طباعة انواعها ؟
#
# ![image-2.png](attachment:image-2.png)
#
# نوع العربه؟ <br>
# عدد اللساتك؟ <br>
# عدد الركاب؟ <br>
# اسم السائق؟ <br>
# الدوله؟ <br>
# هل العربه سوداء؟ <br>
#
#
# يمكنك اضافة اي وصف تريده ....................
